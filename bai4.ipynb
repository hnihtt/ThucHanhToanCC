# %% [markdown]
# <a href="https://colab.research.google.com/github/hnihtt/ThucHanhToanCC/blob/main/bai4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Thực hành 1

# %%
import numpy as np
mienchia = np.linspace(0,2,11)
mienchia
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ])

# %% [markdown]
# #Thực hành 2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fs = [1, 2, 4] 
all_time = np.linspace(0, 2, 200)
t = all_time[:100]

for f in fs:
  y = np.sin(2 * np.pi * f * t)
  plt.plot(t, y, label='{} Hz'.format(f))
plt.legend() 
import os
plt.savefig('basics_python.pdf') 
plt.show()

# %%
fig, ax = plt.subplots() 
for f in fs:
  y = np.sin(2 * np.pi * f * t)
  ax.plot(t, y, label='{} Hz'.format(f))
for f in fs:
  y = np.sin(2 * np.pi * f * t)
  plt.plot(t, y, label='{} Hz'.format(f))

# %% [markdown]
# #Thực hành 4

# %%
def f(x): return x**2
print(f(8))
# Out:
# 64

# %%
g = lambda x: x**2
print(g(8))
# Out:
# 64

# %% [markdown]
# #Thực hành 5

# %%
def thue(phan_tram): return lambda x: x*phan_tram
hcm = thue(0.012)
hn = thue(0.01)

# %%
hcm(1000000)
# Out:
# 12000.0

# %%
hn(1000000)
# Out:
# 10000.0

# %% [markdown]
# #Thực hành 6

# %%
hinhthang = lambda f,a,b: (b-a)*(f(a)+f(b))/2 
from math import exp
hinhthang(exp,0,1)
# Out:
# 1.8591409142295225

# %%
def hai_x(x):
  return 2*x
hinhthang(hai_x,1,2)
# Out:
# 3.0

# %% [markdown]
# #Thực hành 7

# %%
def traprule(ham,trai,phai):
  return (phai-trai)*(ham(trai))+ham(phai)/2

# %%
import math
S = "Bieu thuc can tinh tich phan la e^x:" 
print(S + '[a,b]') 
A = float(input('Nhap a : '))
B = float(input('Nhap b : '))
Y = traprule(math.exp, A, B)
print(S + "[%.1E,%.1E] : " % (A, B))
print('Gia tri xap xi : %.15E' % Y)
E = math.exp(B) - math.exp(A)
print(' Gia tri chinh xac : %.15E' % E)
# Out:
# Bieu thuc can tinh tich phan la e^x:[a,b]
# Nhap a : 0
# Nhap b : 1
# Bieu thuc can tinh tich phan la e^x:[0.0E+00,1.0E+00] :
# Gia tri xap xi : 2.359140914229522E+00
#  Gia tri chinh xac : 1.718281828459045E+00

# %% [markdown]
# #Thực hành 8

# %%
import scipy 
from sympy import *
import sys 
sys.displayhook = pprint
x = Symbol('x')
bt1 = integrate(x**2 + x + 1, x)
pprint (bt1)
bt2 = integrate(x/(x**2+2*x+1), x)
pprint (bt2)
bt3 = integrate(x**2 * exp(x) * cos(x), x)
pprint (bt3)
bt4 = integrate(exp(-x**2)*erf(x), x)
pprint (bt4)
# Out:
#  3    2
# x    x
# ── + ── + x
# 3    2
#                1
# log(x + 1) + ─────
#              x + 1
#  2  x           2  x                         x           x
# x ⋅ℯ ⋅sin(x)   x ⋅ℯ ⋅cos(x)      x          ℯ ⋅sin(x)   ℯ ⋅cos(x)
# ──────────── + ──────────── - x⋅ℯ ⋅sin(x) + ───────── - ─────────
#      2              2                           2           2
#       2
# √π⋅erf (x)
# ──────────
#     4
# None
